# %%
## Q1
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)

if b != 0:
    print("Division:", a / b)   
else:
    print("Division: Cannot divide by zero")

print("Power:", a ** b)
# Out:
# Enter first number:  30
# Enter second number:  19
# Addition: 49
# Subtraction: 11
# Multiplication: 570
# Division: 1.5789473684210527
# Power: 11622614670000000000000000000

# %%
#Q2
my_list = ["apple", "banana", 10, "cherry"]

found = False
for item in my_list:
    if type(item) == int:
        found = True
        break
if found:
    print("The list contains a numeric value.")
else:
    print("The list does not contain any numeric value.")
# Out:
# The list contains a numeric value.

# %%
#Q3
my_dict = {"name": "Ali", "age": 20}

my_dict["city"] = "Rawalpindi"

print(my_dict)
# Out:
# {'name': 'Ali', 'age': 20, 'city': 'Rawalpindi'}

# %%
#Q4
my_dict = {"a": 10, "b": 20, "c": 5}

total = 0
for value in my_dict.values():
    if type(value) == int:
        total += value

print("Total sum:", total)
# Out:
# Total sum: 35

# %%
#Q5
my_list = [1, 2, 3, 2, 4, 5, 1, 6]
duplicates = []

for item in my_list:
    if my_list.count(item) > 1 and item not in duplicates:
        duplicates.append(item)

print("Duplicate values:", duplicates)
# Out:
# Duplicate values: [1, 2]

# %%
#Q6
my_dict = {"name": "Ali", "age": 20}

key_to_check = "age"

if key_to_check in my_dict:
    print("The key already exists in the dictionary.")
else:
    print("The key does not exist in the dictionary.")
# Out:
# The key already exists in the dictionary.
